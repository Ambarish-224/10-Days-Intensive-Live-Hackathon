# %%
## Comment
## Observation

# %%
## Uploading Data to Online Notebook

from google.colab import files
uploaded = files.upload()   ## Uploading Data to Online Notebook
# Out:
#      <input type="file" id="files-4ff8948c-a42d-47be-9f79-da91a8a9bfd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ff8948c-a42d-47be-9f79-da91a8a9bfd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Importing All Necessary Library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')
# %matplotlib inline

# %%
## Uploading Dataset to notebook
df = pd.read_csv("/content/D6__dataset ML.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
## Show Top 5 Rows
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
## Checking he Shape of Dataset
df.shape
# Out:
# (1000, 17)

# %%
## Checking All Information Related with Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
### changing Categorical data into Numeric data

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

df['Branch'] = label_encoder.fit_transform(df['Branch'])
df['City'] = label_encoder.fit_transform(df['City'])
df['Customer type'] = label_encoder.fit_transform(df['Customer type'])
df['Gender'] = label_encoder.fit_transform(df['Gender'])
df['Product line'] = label_encoder.fit_transform(df['Product line'])
df['Date'] = label_encoder.fit_transform(df['Date'])
df['Time'] = label_encoder.fit_transform(df['Time'])
df['Payment'] = label_encoder.fit_transform(df['Payment'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   int64
#  1   City                     1000 non-null   int64
#  2   Customer type            1000 non-null   int64
#  3   Gender                   1000 non-null   int64
#  4   Product line             1000 non-null   int64
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   int64
#  10  Time                     1000 non-null   int64
#  11  Payment                  1000 non-null   int64
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
df.head()
# Out:
#    Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0       0     2              0       0             3       74.69         7
# 1       2     1              1       0             0       15.28         5
# 2       0     2              1       1             4       46.33         7
# 3       0     2              0       1             3       58.22         8
# 4       0     2              1       1             5       86.31         7
#
#     Tax 5%     Total  Date  Time  Payment    cogs  gross margin percentage  \
# 0  26.1415  548.9715     4   146        2  522.83                 4.761905
# 1   3.8200   80.2200    31    23        0   76.40                 4.761905
# 2  16.2155  340.5255    26   155        1  324.31                 4.761905
# 3  23.2880  489.0480    50   485        2  465.76                 4.761905
# 4  30.2085  634.3785    19    29        2  604.17                 4.761905
#
#    gross income  Rating
# 0       26.1415     9.1
# ...

# %%
## Checking total null value present in a dataset
df.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# **Observation:-**
# There is no Missing Value present in above Dataset

# %%
## Checking All Columns Present in Dataset
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
# Display summary statistics for a dataframe
df.describe()
# Out:
#             Branch         City  Customer type       Gender  Product line  \
# count  1000.000000  1000.000000    1000.000000  1000.000000   1000.000000
# mean      0.988000     1.008000       0.499000     0.499000      2.452000
# std       0.817633     0.820127       0.500249     0.500249      1.715412
# min       0.000000     0.000000       0.000000     0.000000      0.000000
# 25%       0.000000     0.000000       0.000000     0.000000      1.000000
# 50%       1.000000     1.000000       0.000000     0.000000      2.000000
# 75%       2.000000     2.000000       1.000000     1.000000      4.000000
# max       2.000000     2.000000       1.000000     1.000000      5.000000
#
#         Unit price     Quantity       Tax 5%        Total         Date  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749    43.499000
# std      26.494628     2.923431    11.708825   245.885335    24.936235
# ...

# %%
df.corr()
# Out:
#                            Branch      City  Customer type    Gender  \
# Branch                   1.000000 -0.507401      -0.019608 -0.056318
# City                    -0.507401  1.000000       0.004899  0.012219
# Customer type           -0.019608  0.004899       1.000000  0.039996
# Gender                  -0.056318  0.012219       0.039996  1.000000
# Product line            -0.053938  0.008811      -0.036800  0.005193
# Unit price               0.028202 -0.013763      -0.020238  0.015445
# Quantity                 0.015964 -0.002121      -0.016763 -0.074258
# Tax 5%                   0.041047 -0.012812      -0.019670 -0.049451
# Total                    0.041047 -0.012812      -0.019670 -0.049451
# Date                    -0.029311  0.015027       0.034184  0.060986
# Time                     0.035921 -0.066115      -0.020162  0.085054
# Payment                 -0.050104  0.019094       0.018073  0.044578
# cogs                     0.041047 -0.012812      -0.019670 -0.049451
# ...

# %%
## Plotting Heatmap to check Covariance

plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), cmap="CMRmap", annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
## Spliting the Dataset into Independent and Dependent Feature

X = df.drop(columns = ['gross income'])
y = df['gross income']

# %%
## Checking All Independent Feature - X
X
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %%
## Checking All Dependent Feature - y
y
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: gross income, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train, Y_test = train_test_split(X,y, test_size = 0.33, random_state =42)

# %%
X_train
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 703       1     0              0       1             3       80.47         9
# 311       2     1              0       1             1       69.33         2
# 722       1     0              1       1             4       44.12         3
# 629       0     2              1       0             1       12.09         1
# 0         0     2              0       0             3       74.69         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 106       2     1              1       1             1       27.38         6
# 270       1     0              1       0             5       67.43         5
# 860       2     1              0       0             4       86.27         1
# 435       2     1              1       1             5       99.24         9
# 102       2     1              1       0             0       23.07         9
#
# ...

# %%
X_train.shape
# Out:
# (670, 15)

# %%
X_test
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 521       2     1              0       0             4       83.17         6
# 737       2     1              1       1             0       58.76        10
# 740       2     1              1       1             4       55.61         7
# 660       1     0              1       0             5       42.97         3
# 411       1     0              1       1             5       21.87         2
# ..      ...   ...            ...     ...           ...         ...       ...
# 506       1     0              0       0             5       48.50         3
# 342       1     0              0       0             3       76.90         7
# 485       1     0              0       0             5       49.49         4
# 711       2     1              0       0             4       75.53         4
# 133       1     0              0       1             0       87.45         6
#
# ...

# %%
X_test.shape
# Out:
# (330, 15)

# %%
Y_train
# Out:
# 703    36.2115
# 311     6.9330
# 722     6.6180
# 629     0.6045
# 0      26.1415
#         ...
# 106     8.2140
# 270    16.8575
# 860     4.3135
# 435    44.6580
# 102    10.3815
# Name: gross income, Length: 670, dtype: float64

# %%
Y_train.shape
# Out:
# (670,)

# %%
Y_test
# Out:
# 521    24.9510
# 737    29.3800
# 740    19.4635
# 660     6.4455
# 411     2.1870
#         ...
# 506     7.2750
# 342    26.9150
# 485     9.8980
# 711    15.1060
# 133    26.2350
# Name: gross income, Length: 330, dtype: float64

# %%
Y_test.shape
# Out:
# (330,)

# %%
## Standardize or Feature Scalling the Dataset

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 3.66938506e-02, -1.22039953e+00, -1.00298954e+00, ...,
#          1.81461993e+00,  0.00000000e+00,  1.27644836e+00],
#        [ 1.26593784e+00, -1.08319485e-02, -1.00298954e+00, ...,
#         -7.33858443e-01,  0.00000000e+00,  1.56676691e+00],
#        [ 3.66938506e-02, -1.22039953e+00,  9.97019367e-01, ...,
#         -7.61276879e-01,  0.00000000e+00,  5.21620115e-01],
#        ...,
#        [ 1.26593784e+00, -1.08319485e-02, -1.00298954e+00, ...,
#         -9.61866678e-01,  0.00000000e+00, -9.53284809e-04],
#        [ 1.26593784e+00, -1.08319485e-02,  9.97019367e-01, ...,
#          2.54982572e+00,  0.00000000e+00,  1.16032094e+00],
#        [ 1.26593784e+00, -1.08319485e-02,  9.97019367e-01, ...,
#         -4.33691847e-01,  0.00000000e+00, -1.22029122e+00]])

# %%
X_test
# Out:
# array([[ 1.26593784, -0.01083195, -1.00298954, ...,  0.83447611,
#          0.        ,  0.17323785],
#        [ 1.26593784, -0.01083195,  0.99701937, ...,  1.21998803,
#          0.        ,  1.16032094],
#        [ 1.26593784, -0.01083195,  0.99701937, ...,  0.35682955,
#          0.        ,  0.87000238],
#        ...,
#        [ 0.03669385, -1.22039953, -1.00298954, ..., -0.47577697,
#          0.        , -0.23320813],
#        [ 1.26593784, -0.01083195, -1.00298954, ..., -0.02245882,
#          0.        ,  0.75387496],
#        [ 0.03669385, -1.22039953, -1.00298954, ...,  0.94623888,
#          0.        ,  1.04419351]])

# %% [markdown]
# ## Model Training

# %%
## Linear Regression
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression
# Out:
# LinearRegression()

# %%
regression.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
## Prediction for the Test data
reg_pred = regression.predict(X_test)

# %%
reg_pred
# Out:
# array([24.951 , 29.38  , 19.4635,  6.4455,  2.187 , 29.475 ,  6.087 ,
#        34.8425, 21.4335,  6.5775, 20.13  , 22.068 , 10.1325, 12.012 ,
#        13.8135, 15.768 , 27.984 , 10.326 , 36.065 ,  8.814 , 19.818 ,
#         7.916 ,  6.096 ,  5.986 , 11.8035,  9.314 , 35.3475,  1.476 ,
#         6.9325,  2.689 ,  3.5975, 29.    ,  4.5805, 20.608 ,  9.191 ,
#         8.3   , 31.78  ,  9.459 ,  9.194 ,  9.183 , 10.226 , 43.935 ,
#         3.5575,  8.613 ,  4.4305, 19.084 , 10.566 ,  3.2495, 16.344 ,
#        13.389 , 20.51  ,  4.84  ,  3.29  , 12.854 ,  8.64  , 23.5325,
#        21.9775,  2.896 , 21.728 , 10.578 ,  5.768 ,  1.616 ,  4.036 ,
#        44.8785, 18.1615, 24.315 , 17.625 , 36.212 , 44.74  ,  5.631 ,
#        18.639 ,  6.06  , 13.959 ,  4.2415,  3.124 , 33.208 , 36.39  ,
#        12.048 ,  3.655 , 35.516 , 14.55  ,  3.347 , 16.7895, 29.283 ,
#        10.3845, 12.885 ,  3.291 , 39.48  , 18.32  , 18.852 , 24.9225,
# ...

# %%
## R Squared and Adjusted R Squared

## R Squared
from sklearn.metrics import r2_score
score=r2_score(Y_test,reg_pred)
print(score)
# Out:
# 1.0

# %%
## Adjusted R square
#display adjusted R-squared
1 - (1-score)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
# Out:
# 1.0

# %%
## Thank YOu
